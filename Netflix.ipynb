# %% [markdown]
# <a href="https://colab.research.google.com/github/Swarn36/Pandas_excercise/blob/main/Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe(include="object")
# Out:
#        show_id   type    title                director         cast  \
# count     5332   5332     5332                    5332         5332
# unique    5332      2     5332                    3945         5200
# top         s8  Movie  Sankofa  Raúl Campos, Jan Suter  Samuel West
# freq         1   5185        1                      18           10
#
#               country rating duration                     listed_in  \
# count            5332   5332     5332                          5332
# unique            604     14      198                           335
# top     United States  TV-MA   94 min  Dramas, International Movies
# freq             1846   1822      135                           336
#
#                                               description
# count                                                5332
# unique                                               5321
# top     When pretty new neighbor Seema falls for their...
# ...

# %%
df.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
df['rating'].value_counts(normalize = True)
# Out:
# TV-MA       0.341710
# TV-14       0.227682
# R           0.145911
# PG-13       0.088147
# TV-PG       0.080833
# PG          0.051575
# TV-G        0.015754
# TV-Y7       0.014254
# TV-Y        0.014254
# NR          0.010878
# G           0.007502
# TV-Y7-FV    0.000563
# UR          0.000563
# NC-17       0.000375
# Name: rating, dtype: float64

# %%
df['type'].value_counts(normalize = True)
# Out:
# Movie      0.972431
# TV Show    0.027569
# Name: type, dtype: float64

# %% [markdown]
# `97.2% are in the Movie groups`

# %%
df['type'].value_counts()
# Out:
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %%
df['release_year'].mean()
# Out:
# 2012.7421230307577

# %%
df[df['type'] == 'Movie'].describe()
# Out:
#        release_year
# count   5185.000000
# mean    2012.613308
# std        9.706731
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
df.loc[0:4, 'show_id':'director']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director]
# Index: []

# %%
df.apply(np.max)
# Out:
# show_id                                                      s997
# type                                                      TV Show
# title                                                     반드시 잡는다
# director                                             Şenol Sönmez
# cast            Ṣọpẹ́ Dìrísù, Wunmi Mosaku, Matt Smith, Malaik...
# country                                                  Zimbabwe
# date_added                                    2021-09-24 00:00:00
# release_year                                                 2021
# rating                                                         UR
# duration                                                   99 min
# listed_in                                               Thrillers
# description     Zixin is about to marry Qihong, but her galliv...
# dtype: object

# %%
df[df['type'] == 'Movie'].apply(np.max)
# Out:
# show_id                                                      s997
# type                                                        Movie
# title                                                     반드시 잡는다
# director                                             Şenol Sönmez
# cast            Ṣọpẹ́ Dìrísù, Wunmi Mosaku, Matt Smith, Malaik...
# country                                                  Zimbabwe
# date_added                                    2021-09-24 00:00:00
# release_year                                                 2021
# rating                                                         UR
# duration                                                   99 min
# listed_in                                               Thrillers
# description     Zixin is about to marry Qihong, but her galliv...
# dtype: object

# %%
df[df['country'].apply(lambda c: c[0] == 'A')].head()
# Out:
#     show_id   type                                title            director  \
# 137    s138  Movie      Crocodile Dundee in Los Angeles        Simon Wincer
# 140    s141  Movie  El patrón, radiografía de un crimen  Sebastián Schindel
# 303    s304  Movie                 Esperando la carroza     Alejandro Doria
# 305    s306  Movie                          Tango Feroz     Marcelo Piñeyro
# 393    s394  Movie            A Second Chance:  Rivals!           Clay Glen
#
#                                                   cast  \
# 137  Paul Hogan, Linda Kozlowski, Jere Burns, Jonat...
# 140  Joaquín Furriel, Luis Ziembrowski, Guillermo P...
# 303  Luis Brandoni, China Zorrilla, Antonio Gasalla...
# 305  Fernán Mirás, Cecilia Dopazo, Imanol Arias, Hé...
# 393  Emily Morris, Stella Shute, Eva Grados, India ...
#
#                       country date_added  release_year rating duration  \
# 137  Australia, United States 2021-09-01          2001     PG   95 min
# ...

# %%
len(df[df['country'].apply(lambda c: c[0] == 'A')])
# Out:
# 111

# %%
df['country'].apply(lambda c: c[0] == 'I').value_counts()
# Out:
# False    4263
# True     1069
# Name: country, dtype: int64

# %%
df[df['country'].apply(lambda c: c[0] == 'I')].head()
# Out:
#     show_id   type             title              director  \
# 24      s25  Movie             Jeans            S. Shankar
# 105    s106  Movie  Angamaly Diaries  Lijo Jose Pellissery
# 114    s115  Movie            Anjaam          Rahul Rawail
# 116    s117  Movie            Dhanak       Nagesh Kukunoor
# 118    s119  Movie           Gurgaon         Shanker Raman
#
#                                                   cast country date_added  \
# 24   Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India 2021-09-21
# 105  Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India 2021-09-05
# 114  Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Jo...   India 2021-09-02
# 116  Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India 2021-09-02
# 118  Akshay Oberoi, Pankaj Tripathi, Ragini Khanna,...   India 2021-09-02
#
#      release_year rating duration  \
# 24           1998  TV-14  166 min
# 105          2017  TV-14  128 min
# 114          1994  TV-14  143 min
# ...

# %%
df.groupby(by = "rating")['country'].describe(percentiles =[])
# Out:
#          count unique            top freq
# rating
# G           40     12  United States   28
# NC-17        2      2         Canada    1
# NR          58     23  United States   24
# PG         275     66  United States  160
# PG-13      470    119  United States  281
# R          778    181  United States  433
# TV-14     1214    129          India  516
# TV-G        84     25  United States   33
# TV-MA     1822    242  United States  537
# TV-PG      431     83          India  116
# TV-Y        76     19  United States   35
# TV-Y7       76     28  United States   33
# TV-Y7-FV     3      3  United States    1
# UR           3      3         France    1

# %%
pd.crosstab(df["rating"], df['type'], normalize=True)
# Out:
# type         Movie   TV Show
# rating
# G         0.007502  0.000000
# NC-17     0.000375  0.000000
# NR        0.010878  0.000000
# PG        0.051575  0.000000
# PG-13     0.088147  0.000000
# R         0.145911  0.000000
# TV-14     0.220743  0.006939
# TV-G      0.015191  0.000563
# TV-MA     0.326519  0.015191
# TV-PG     0.078020  0.002813
# TV-Y      0.013316  0.000938
# TV-Y7     0.013128  0.001125
# TV-Y7-FV  0.000563  0.000000
# UR        0.000563  0.000000

# %%
df['country'].head()
# Out:
# 7     United States, Ghana, Burkina Faso, United Kin...
# 8                                        United Kingdom
# 9                                         United States
# 12                              Germany, Czech Republic
# 24                                                India
# Name: country, dtype: object

# %%
df.loc[:, 'type':'rating']
# Out:
#          type                          title             director  \
# 7       Movie                        Sankofa         Haile Gerima
# 8     TV Show  The Great British Baking Show      Andy Devonshire
# 9       Movie                   The Starling       Theodore Melfi
# 12      Movie                   Je Suis Karl  Christian Schwochow
# 24      Movie                          Jeans           S. Shankar
# ...       ...                            ...                  ...
# 8801    Movie                        Zinzana      Majid Al Ansari
# 8802    Movie                         Zodiac        David Fincher
# 8804    Movie                     Zombieland      Ruben Fleischer
# 8805    Movie                           Zoom         Peter Hewitt
# 8806    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
sns.countplot(data = df, x = 'type', hue = 'rating')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
pd.crosstab(df["rating"], df['type'], margins=True)
# Out:
# type      Movie  TV Show   All
# rating
# G            40        0    40
# NC-17         2        0     2
# NR           58        0    58
# PG          275        0   275
# PG-13       470        0   470
# R           778        0   778
# TV-14      1177       37  1214
# TV-G         81        3    84
# TV-MA      1741       81  1822
# TV-PG       416       15   431
# TV-Y         71        5    76
# TV-Y7        70        6    76
# TV-Y7-FV      3        0     3
# UR            3        0     3
# All        5185      147  5332
